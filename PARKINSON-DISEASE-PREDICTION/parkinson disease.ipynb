# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
df=pd.read_csv('Parkinsson disease.csv')

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
data={'MDVP:Fo(Hz)':'col1','MDVP:Fhi(Hz)':'col2','MDVP:Flo(Hz)':'col3','MDVP:Jitter(%)':'col4','MDVP:Jitter(Abs)':'col5',
     'MDVP:RAP':'col6','MDVP:PPQ':'col7','Jitter:DDP':'col8','MDVP:Shimmer':'col9'}

# %%
df.rename(columns=data,inplace=True)

# %%
data1={'MDVP:Shimmer(dB)':'col10', 'Shimmer:APQ3':'col111','Shimmer:APQ5':'col122','MDVP:APQ':'col13','Shimmer:DDA':'col14',
      'NHR':'col15','HNR':'col16','RPDE':'col17','DFA':'col18','spread1':'col19','spread2':'col20','D2':'col21','PPE':'col22'}

# %%
df.rename(columns=data1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    195 non-null    object
#  1   col1    195 non-null    float64
#  2   col2    195 non-null    float64
#  3   col3    195 non-null    float64
#  4   col4    195 non-null    float64
#  5   col5    195 non-null    float64
#  6   col6    195 non-null    float64
#  7   col7    195 non-null    float64
#  8   col8    195 non-null    float64
#  9   col9    195 non-null    float64
#  10  col10   195 non-null    float64
#  11  col111  195 non-null    float64
#  12  col122  195 non-null    float64
#  13  col13   195 non-null    float64
#  14  col14   195 non-null    float64
#  15  col15   195 non-null    float64
#  16  col16   195 non-null    float64
#  17  status  195 non-null    int64
#  18  col17   195 non-null    float64
#  19  col18   195 non-null    float64
# ...

# %%
df.describe()
# Out:
#              col1        col2        col3        col4        col5        col6  \
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean   154.228641  197.104918  116.324631    0.006220    0.000044    0.003306
# std     41.390065   91.491548   43.521413    0.004848    0.000035    0.002968
# min     88.333000  102.145000   65.476000    0.001680    0.000007    0.000680
# 25%    117.572000  134.862500   84.291000    0.003460    0.000020    0.001660
# 50%    148.790000  175.829000  104.315000    0.004940    0.000030    0.002500
# 75%    182.769000  224.205500  140.018500    0.007365    0.000060    0.003835
# max    260.105000  592.030000  239.170000    0.033160    0.000260    0.021440
#
#              col7        col8        col9       col10  ...       col14  \
# count  195.000000  195.000000  195.000000  195.000000  ...  195.000000
# mean     0.003446    0.009920    0.029709    0.282251  ...    0.046993
# ...

# %%
df['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
df.groupby('status').mean()

# %%
x=df.drop(columns=['name','status'],axis=1)
y=df['status']

# %%
x
# Out:
#         col1     col2     col3     col4     col5     col6     col7     col8  \
# 0    119.992  157.302   74.997  0.00784  0.00007  0.00370  0.00554  0.01109
# 1    122.400  148.650  113.819  0.00968  0.00008  0.00465  0.00696  0.01394
# 2    116.682  131.111  111.555  0.01050  0.00009  0.00544  0.00781  0.01633
# 3    116.676  137.871  111.366  0.00997  0.00009  0.00502  0.00698  0.01505
# 4    116.014  141.781  110.655  0.01284  0.00011  0.00655  0.00908  0.01966
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 190  174.188  230.978   94.261  0.00459  0.00003  0.00263  0.00259  0.00790
# 191  209.516  253.017   89.488  0.00564  0.00003  0.00331  0.00292  0.00994
# 192  174.688  240.005   74.287  0.01360  0.00008  0.00624  0.00564  0.01873
# 193  198.764  396.961   74.904  0.00740  0.00004  0.00370  0.00390  0.01109
# 194  214.289  260.277   77.973  0.00567  0.00003  0.00295  0.00317  0.00885
#
# ...

# %%
x.columns
# Out:
# Index(['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9',
#        'col10', 'col111', 'col122', 'col13', 'col14', 'col15', 'col16',
#        'col17', 'col18', 'col19', 'col20', 'col21', 'col22'],
#       dtype='object')

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: status, dtype: int64

# %%
scaler=StandardScaler()

# %%
scaler.fit(x)
# Out:
# StandardScaler()

# %%
s_df=scaler.transform(x)

# %%
print(s_df)
# Out:
# [[-0.82929965 -0.43616456 -0.95203729 ...  0.48047686 -0.21053082
#    0.86888575]
#  [-0.77097169 -0.53097409 -0.05772056 ...  1.31118546  0.27507712
#    1.80360503]
#  [-0.90947638 -0.7231683  -0.10987483 ...  1.01768236 -0.10362861
#    1.40266141]
#  ...
#  [ 0.49557839  0.47010361 -0.96839309 ... -0.81807931  0.78033848
#   -0.83241014]
#  [ 1.07876114  2.19004398 -0.95417967 ... -0.22906571 -0.63700298
#   -0.92610456]
#  [ 1.45481664  0.69224632 -0.88348115 ... -0.43085284  0.45480231
#   -0.64505466]]

# %%
X=s_df
Y=df['status']

# %%
X
# Out:
# array([[-0.82929965, -0.43616456, -0.95203729, ...,  0.48047686,
#         -0.21053082,  0.86888575],
#        [-0.77097169, -0.53097409, -0.05772056, ...,  1.31118546,
#          0.27507712,  1.80360503],
#        [-0.90947638, -0.7231683 , -0.10987483, ...,  1.01768236,
#         -0.10362861,  1.40266141],
#        ...,
#        [ 0.49557839,  0.47010361, -0.96839309, ..., -0.81807931,
#          0.78033848, -0.83241014],
#        [ 1.07876114,  2.19004398, -0.95417967, ..., -0.22906571,
#         -0.63700298, -0.92610456],
#        [ 1.45481664,  0.69224632, -0.88348115, ..., -0.43085284,
#          0.45480231, -0.64505466]])

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=y,random_state=2)

# %%
model=SVC(kernel='linear')
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
train_shape=[x.shape,X_train.shape,Y_train.shape]
test_shape=[X_test.shape,Y_test.shape]

# %%
print(train_shape)
print(test_shape)
# Out:
# [(195, 22), (156, 22), (156,)]
# [(39, 22), (39,)]

# %%
y_pred=model.predict(X_train)
accuracy=accuracy_score(Y_train,y_pred)

# %%
print(accuracy)
# Out:
# 0.8910256410256411

# %%
y1_pred=model.predict(X_test)
accuracy=accuracy_score(y1_pred,Y_test)

# %%
print(accuracy)
# Out:
# 0.8974358974358975

# %%
input_data=(119.992,157.302,74.997,0.00784,0.00007,0.0037,0.00554,0.01109,0.04374,0.426,0.02182,0.0313,0.02971,0.06545,0.02211,21.033,0.414783,0.815285,-4.813031,0.266482,2.301442,0.284654)
in_array=np.asarray(input_data)
in_reshape=in_array.reshape(1,-1)
scale_df=scaler.transform(in_reshape)
prediction=model.predict(scale_df)
print(prediction)

if (prediction[0]==0):
    print('the person does not have diabetic disease')
else:
    print('the person have diabetic disease')
# Out:
# [1]
# the person have diabetic disease
# C:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
filename='trained_model03.sav'
pickle.dump(model,open(filename,'wb'))

# %%
load=pickle.load(open('trained_model03.sav','rb'))

# %%
input_data=(119.992,157.302,74.997,0.00784,0.00007,0.0037,0.00554,0.01109,0.04374,0.426,0.02182,0.0313,0.02971,0.06545,0.02211,21.033,0.414783,0.815285,-4.813031,0.266482,2.301442,0.284654)
in_array=np.asarray(input_data)
in_reshape=in_array.reshape(1,-1)
scale_df=scaler.transform(in_reshape)
prediction=load.predict(scale_df)
print(prediction)

if (prediction[0]==0):
    print('the person does not have diabetic disease')
else:
    print('the person have diabetic disease')
# Out:
# [1]
# the person have diabetic disease
# C:\Users\moham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
